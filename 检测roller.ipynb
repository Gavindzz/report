# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
file1= "/media/gavin/My Passport/train/IMG_2664.jpg"
file2="/media/gavin/My Passport/train/IMG_2669.jpg"

# %%
img=Image.open('IMG_2664.jpg')
plt.figure("IMG_2664")
plt.imshow(img)
plt.show()
img=Image.open('IMG_2665.jpg')
plt.figure("IMG_2665")
plt.imshow(img)
plt.show()

# %%
image1 = cv2.imread(file1)
image2 = cv2.imread(file2)
difference = cv2.subtract(image1, image2)
result = not np.any(difference)

# %%
if result is True:
     print("两张图片一样")
else:
     cv2.imwrite("result.jpg", difference)
     print ("两张图片不一样")
# Out:
# 两张图片一样

# %%
import matplotlib.pyplot as plt # plt 用于显示图片
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy as np
 
lena = mpimg.imread('IMG_2664.jpg') # 读取和代码处于同一目录下的 lena.png
# 此时 lena 就已经是一个 np.array 了，可以对它进行任意处理
lena.shape#(512, 512, 3)
 
plt.imshow(lena) # 显示图片
plt.axis('off') # 不显示坐标轴
plt.show()
